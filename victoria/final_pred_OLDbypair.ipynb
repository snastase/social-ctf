# %% [markdown]
# # Cross-Validated PC Predictions
# Setup environment

# %%
import numpy as np
from itertools import combinations

n_repeats = 32
n_maps = 32
n_samples = 4501
n_players = 4
n_pairs = n_players * (n_players - 1) / 2
pairs = combinations(np.arange(n_players), 2)
n_pcs = 142

datadir = '/jukebox/hasson/snastase/social-ctf/results'

# %% [markdown]
# Read in LSTM data.
# lstms has shape 32 maps, 32 repeats, 4501 samples, 4 players, 142 PCs. lstms_stack collapses this to 32*32*4501 samples, 4 players, and 142 PCs.

# %%
from scipy.stats import zscore

# data shape = (2 repeats, 4 players, 4501 samples, 142 PCs)
lstms = np.full((n_maps, n_repeats, n_samples, n_players, n_pcs), np.nan, dtype='uint8')
map_ids = []
for map_id in np.arange(n_maps):
    for repeat_id in np.arange(n_repeats):
        data = np.load(f'{datadir}/lstms-pca_matchup-0_map-{map_id}_repeat-{repeat_id}.npy')
        lstms[map_id, repeat_id] = zscore(np.moveaxis(data[..., :n_pcs], 0, 1), axis=0)
        map_ids.extend([map_id]*n_samples)
    print(f'Finished loading {map_id}')
print(f'LSTMs shape: {lstms.shape}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_147847/43201878.py in <module>
#       7     for repeat_id in np.arange(n_repeats):
#       8         data = np.load(f'{datadir}/lstms-pca_matchup-0_map-{map_id}_repeat-{repeat_id}.npy')
# ----> 9         lstms[map_id, repeat_id] = zscore(np.moveaxis(data[..., :n_pcs], 0, 1), axis=0)
#      10         map_ids.extend([map_id]*n_samples)
#      11     print(f'Finished loading {map_id}')
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/scipy/stats/stats.py in zscore(a, axis, ddof, nan_policy)
#    2472            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2473     """
# -> 2474     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#    2475
#    2476
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/scipy/stats/stats.py in zmap(scores, compare, axis, ddof, nan_policy)
#    2543     else:
#    2544         mn = a.mean(axis=axis, keepdims=True)
# -> 2545         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2546         if axis is None:
#    2547             isconst = (a.item(0) == a).all()
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/numpy/core/_methods.py in _std(a, axis, dtype, out, ddof, keepdims, where)
#     260          where=True):
#     261     ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# --> 262                keepdims=keepdims, where=where)
#     263
#     264     if isinstance(ret, mu.ndarray):
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/numpy/core/_methods.py in _var(a, axis, dtype, out, ddof, keepdims, where)
#     227     # Note that x may not be inexact and that we need it to be an array,
#     228     # not a scalar.
# --> 229     x = asanyarray(arr - arrmean)
#     230
#     231     if issubclass(arr.dtype.type, (nt.floating, nt.integer)):
#
# KeyboardInterrupt:

# %%
from scipy.stats import zscore

# data shape = (2 repeats, 4 players, 4501 samples, 142 PCs)
lstms = np.full((n_maps, n_repeats, n_samples, n_players, n_pcs), np.nan, dtype='uint8')
map_ids = []
for map_id in np.arange(n_maps):
    for repeat_id in np.arange(n_repeats):
        map_ids.extend([map_id]*n_samples)

# %%
lstms_stack = np.dstack(np.split(lstms, n_repeats, axis=1)).squeeze() #32 x 144032 x 2
lstms_stack = np.hstack(np.split(lstms_stack, n_maps, axis=0)).squeeze()
print(f'LSTMs stack shape: {lstms_stack.shape}')
# Out:
# LSTMs stack shape: (4609024, 4, 142)

# %%
np.save('lstms_stack.npy', lstms_stack)

# %%
lstms_stack = np.load('lstms_stack.npy')

# %%
len(map_ids)
# Out:
# 4609024

# %% [markdown]
# Perform an ISC regression for each PC and pair. results is of shape 142 PCs, 6 pairs, 1024 folds (32 maps * 32 repeats)

# %%
from sklearn.model_selection import PredefinedSplit
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
cv = PredefinedSplit(map_ids)

coefs = np.full((n_pcs, int(n_pairs), n_maps*n_repeats), np.nan)
results = np.full((n_pcs, int(n_pairs), n_maps), np.nan)  #n_repeats
for pc_id in np.arange(n_pcs):
    pairs = combinations(np.arange(n_players), 2)
    for pair_id, pair in enumerate(pairs):
        result = []
        ##coef = []
        for fold, (train, test) in enumerate(cv.split()):
            reg = LinearRegression()
            reg.fit(lstms_stack[train, pair[0], pc_id][:, np.newaxis], 
                    lstms_stack[train, pair[1], pc_id])
            #if pc_id==1:
            #    raise
            coefs[pc_id, pair_id, fold] = reg.coef_
            ##coef.extend([reg.coef_ for i in range(n_repeats)])
            pred = reg.predict(lstms_stack[test, pair[0], pc_id][:, np.newaxis])
            result.extend([pearsonr(p, t)[0] for p, t in
                           zip(np.split(pred, n_repeats, axis=0),
                               np.split(lstms_stack[test, pair[1], pc_id], n_repeats, axis=0))])
        print(f"Finished ISC regression for PC {pc_id}, pair {pair_id}") #fold {fold}
        results[pc_id, pair_id] = np.array(result)
        ##coefs[pc_id, pair_id] = np.array(coef)
# Out:
# Finished ISC regression for PC 0, pair 0
# Finished ISC regression for PC 0, pair 1
# Finished ISC regression for PC 0, pair 2
# Finished ISC regression for PC 0, pair 3
# Finished ISC regression for PC 0, pair 4
# Finished ISC regression for PC 0, pair 5
# Finished ISC regression for PC 1, pair 0
# Finished ISC regression for PC 1, pair 1
# Finished ISC regression for PC 1, pair 2
# Finished ISC regression for PC 1, pair 3
# Finished ISC regression for PC 1, pair 4
# Finished ISC regression for PC 1, pair 5
# Finished ISC regression for PC 2, pair 0
# Finished ISC regression for PC 2, pair 1
# Finished ISC regression for PC 2, pair 2
# Finished ISC regression for PC 2, pair 3
# Finished ISC regression for PC 2, pair 4
# Finished ISC regression for PC 2, pair 5
# Finished ISC regression for PC 3, pair 0
# Finished ISC regression for PC 3, pair 1
# Finished ISC regression for PC 3, pair 2
# Finished ISC regression for PC 3, pair 3
# Finished ISC regression for PC 3, pair 4
# Finished ISC regression for PC 3, pair 5
# Finished ISC regression for PC 4, pair 0
# Finished ISC regression for PC 4, pair 1
# Finished ISC regression for PC 4, pair 2
# Finished ISC regression for PC 4, pair 3
# Finished ISC regression for PC 4, pair 4
# Finished ISC regression for PC 4, pair 5
# Finished ISC regression for PC 5, pair 0
# Finished ISC regression for PC 5, pair 1
# Finished ISC regression for PC 5, pair 2
# Finished ISC regression for PC 137, pair 3
# Finished ISC regression for PC 137, pair 4
# Finished ISC regression for PC 137, pair 5
# Finished ISC regression for PC 138, pair 0
# Finished ISC regression for PC 138, pair 1
# Finished ISC regression for PC 138, pair 2
# Finished ISC regression for PC 138, pair 3
# Finished ISC regression for PC 138, pair 4
# Finished ISC regression for PC 138, pair 5
# Finished ISC regression for PC 139, pair 0
# Finished ISC regression for PC 139, pair 1
# Finished ISC regression for PC 139, pair 2
# Finished ISC regression for PC 139, pair 3
# Finished ISC regression for PC 139, pair 4
# Finished ISC regression for PC 139, pair 5
# Finished ISC regression for PC 140, pair 0
# Finished ISC regression for PC 140, pair 1
# Finished ISC regression for PC 140, pair 2
# Finished ISC regression for PC 140, pair 3
# Finished ISC regression for PC 140, pair 4
# Finished ISC regression for PC 140, pair 5
# Finished ISC regression for PC 141, pair 0
# Finished ISC regression for PC 141, pair 1
# Finished ISC regression for PC 141, pair 2
# Finished ISC regression for PC 141, pair 3
# Finished ISC regression for PC 141, pair 4
# Finished ISC regression for PC 141, pair 5

# %%
from sklearn.model_selection import PredefinedSplit
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
cv = PredefinedSplit(map_ids)

coefs = np.full((n_pcs, int(n_pairs), n_maps*n_repeats), np.nan)
results = np.full((n_pcs, int(n_pairs), n_maps), np.nan)
for pc_id in np.arange(2):
    pairs = combinations(np.arange(n_players), 2)
    for pair_id, pair in enumerate(pairs):
        result = []
        for fold, (train, test) in enumerate(cv.split()):
            reg = LinearRegression()
            reg.fit(lstms_stack[train, pair[0], pc_id][:, np.newaxis], 
                    lstms_stack[train, pair[1], pc_id])
            #if pc_id==1:
            #    raise
            #print(pc_id, pair_id, fold, reg.coef_)
            coefs[pc_id, pair_id, fold] = reg.coef_
            pred = reg.predict(lstms_stack[test, pair[0], pc_id][:, np.newaxis])
            #result.extend([pearsonr(p, t)[0] for p, t in
            #               zip(np.split(pred, n_repeats, axis=0),
            #                   np.split(lstms_stack[test, pair[1], pc_id], n_repeats, axis=0))])
        print(f"Finished ISC regression for PC {pc_id}, pair {pair_id}") #fold {fold}
        results[pc_id, pair_id] = np.array(result)

# %%
results.shape
# Out:
# (142, 6, 1024)

# %%
coefs.shape
# Out:
# (142, 6, 32)

# %%
coefs = coefs[:,:,:n_maps]

# %%
np.argwhere(np.isnan(coefs))#np.ndarray.tolist()[:,2])
# Out:
# array([], shape=(0, 3), dtype=int64)

# %%
pairs = combinations(np.arange(n_players), 2)
for i, x in enumerate(pairs):
    print(i,x)
# Out:
# 0 (0, 1)
# 1 (0, 2)
# 2 (0, 3)
# 3 (1, 2)
# 4 (1, 3)
# 5 (2, 3)

# %%
np.save('cvISC_coefs.npy', coefs)

# %%
np.save('regression_results.npy', results)

# %%
results = np.load('regression_results.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_185432/2303259601.py in <module>
# ----> 1 results = np.load('regression_results.npy')
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'regression_results.npy'

# %%
coefs = np.load('cvISC_coefs.npy')

# %% [markdown]
# Make a dataframe of cooperative and competitive ISCs

# %%
import pandas as pd

results_df_dict_full = {'PC': [], 'coop coef': [], 'comp coef': [], 'cooperative cvISC': [], 'competitive cvISC': [], 'cooperative-competitive cvISC difference': []}

coop_ids = (0, 5)
comp_ids = (1, 2, 3, 4)
for pc_id in np.arange(n_pcs): 
    for map_id in np.arange(n_maps):
        for repeat_id in np.arange(n_repeats):
            game_id=map_id*n_repeats+repeat_id
            coop = np.mean(results[pc_id, coop_ids, game_id], axis=0)
            comp = np.mean(results[pc_id, comp_ids, game_id], axis=0)
            #if not np.isnan(coefs[pc_id, 5, game_id]):
            #print(coefs[pc_id, coop_ids, game_id])
            coop_coef = np.mean(coefs[pc_id, coop_ids, map_id], axis=0)
            comp_coef = np.mean(coefs[pc_id, comp_ids, map_id], axis=0)
            results_df_dict_full['cooperative cvISC'].append(coop)
            results_df_dict_full['competitive cvISC'].append(comp)
            results_df_dict_full['cooperative-competitive cvISC difference'].append(coop-comp)
            results_df_dict_full['PC'].append(pc_id + 1)
            results_df_dict_full['coop coef'].append(coop_coef)
            results_df_dict_full['comp coef'].append(comp_coef)

results_df_full = pd.DataFrame(results_df_dict_full)
results_df_full
# Out:
#          PC  coop coef  comp coef  cooperative cvISC  competitive cvISC  \
# 0         1  -0.009346  -0.030464          -0.000558          -0.000288
# 1         1  -0.009346  -0.030464           0.022159           0.011377
# 2         1  -0.009346  -0.030464           0.059278           0.072876
# 3         1  -0.009346  -0.030464           0.019093           0.019256
# 4         1  -0.009346  -0.030464           0.066834           0.016448
# ...     ...        ...        ...                ...                ...
# 145403  142   0.022855   0.009780          -0.008464           0.003550
# 145404  142   0.022855   0.009780           0.023937           0.019353
# 145405  142   0.022855   0.009780           0.035792           0.037537
# 145406  142   0.022855   0.009780           0.041881           0.005123
# 145407  142   0.022855   0.009780           0.037810           0.046218
#
#         cooperative-competitive cvISC difference
# 0                                      -0.000270
# 1                                       0.010782
# 2                                      -0.013598
# 3                                      -0.000163
# 4                                       0.050386
# ...                                          ...
# 145403                                 -0.012013
# 145404                                  0.004585
# 145405                                 -0.001745
# 145406                                  0.036758
# 145407                                 -0.008408
#
# [145408 rows x 6 columns]

# %% [markdown]
# Plot cvISC for cooperative and competitive pairs for each PC

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#cols = ['red' if np.mean(results_df_full[results_df_full['PC']==x]['cooperative cvISC']) < 
#        np.mean(results_df_full[results_df_full['PC']==x]['competitive cvISC']) 
#        else 'blue' for x in range(142)]
cols = ['red' if np.mean(results_df_full[results_df_full['PC']==x]['coop coef']) < 0
       else 'blue' for x in range(1,143)]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='cooperative cvISC', data=results_df_full, palette=cols) #color='gray')
ax.set_ylim(0, .4) #was using .6?
ax.set_title('Cooperative cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('cooperative cvISC', fontsize=16);
fig.savefig("coop_cvISC.png")

# %%
results_df_full[results_df_full['PC']==1]['coop coef']
# Out:
# 0      -0.009346
# 1      -0.009346
# 2      -0.009346
# 3      -0.009346
# 4      -0.009346
#           ...
# 1019   -0.009891
# 1020   -0.009891
# 1021   -0.009891
# 1022   -0.009891
# 1023   -0.009891
# Name: coop coef, Length: 1024, dtype: float64

# %%
np.mean([np.nan, 5])<0
# Out:
# False

# %%
#cols = ['red' if np.mean(results_df_full[results_df_full['PC']==x]['cooperative cvISC']) < 
#        np.mean(results_df_full[results_df_full['PC']==x]['competitive cvISC']) 
#        else 'blue' for x in range(142)]
cols = ['red' if np.mean(results_df_full[results_df_full['PC']==x]['comp coef']) < 0
       else 'blue' for x in range(1,143)]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='competitive cvISC', data=results_df_full, palette=cols)# color='gray')
ax.set_ylim(0, .4) #was using .6?
ax.set_title('Competitive Pair cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('competitive cvISC', fontsize=16);
fig.savefig("comp_cvISC.png")

# %% [markdown]
# ### Wins and Score Prediction
# Load wins and scores data

# %%
wins = np.load(f'/jukebox/hasson/snastase/social-ctf/results/wins_matchup-0.npy')
scores = np.load(f'/jukebox/hasson/snastase/social-ctf/results/scores_matchup-0.npy')

# %%
wins_stack = np.hstack(np.split(wins, n_repeats, axis=0)).squeeze() #32 x 144032 x 2
print(f"Wins stack shape: {wins_stack.shape}")
scores_stack = np.hstack(np.split(scores, n_repeats, axis=0)).squeeze() #32 x 144032 x 2
print(f"Scores stack shape: {scores_stack.shape}")
# Out:
# Wins stack shape: (1024, 2)
# Scores stack shape: (1024, 2)

# %% [markdown]
# Predict wins using cvISC. results_wins is of shape 142 PCs, 2 teams, 32 folds

# %% [markdown]
# Fit a logistic regression for each fold to predict wins using cvISC. results_wins is of shape 142 PCs, 2 teams, 32 folds

# %%
from sklearn.model_selection import PredefinedSplit

# Create a new split over games (not samples)
map_ids_2 = []
for map_id in np.arange(n_maps):
    for repeat_id in np.arange(n_repeats):
        map_ids_2.append(map_id)
        
cv2 = PredefinedSplit(map_ids_2)

# %%
###########################JUNK################################



from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

results_wins = np.full((n_pcs, 2, n_maps), np.nan)   #n_repeats
coefs_wins = np.full((n_pcs, 2, n_maps), np.nan)   #n_repeats
for pc_id in np.arange(n_pcs):
    pairs = [(0, (0,1)), (5, (2,3))]
    for pair_id, pair in pairs:
        scores = []
        for f, (train, test) in enumerate(cv2.split()):
            # Initialize simple classifier
            clf = LogisticRegression(penalty='none', max_iter=300, class_weight='balanced') 

            # Z-score training SPIs and test SPIs (based on training set)
            results_train = zscore(results[pc_id, pair_id, train][:, np.newaxis]) 
            results_test = zscore(results[pc_id, pair_id, test][:, np.newaxis])

            # Train competitive/cooperative classifier based on train SPIs
            clf.fit(results_train, wins_stack[train, pair_id//5])

            # Use fitted classifier to predict test cooperative/competitive 
            pred = clf.predict(results_test)

            # Evaluate classifier accuracy
            score = accuracy_score(wins_stack[test, pair_id//5], pred)
            scores.append(score)
            
            
        results_wins[pc_id, pair_id//5] = np.array(scores)
# Finished wins regression for PC 109
# Finished wins regression for PC 110
# Finished wins regression for PC 111
# Finished wins regression for PC 112
# Finished wins regression for PC 113
# Finished wins regression for PC 114
# Finished wins regression for PC 115
# Finished wins regression for PC 116
# Finished wins regression for PC 117
# Finished wins regression for PC 118
# Finished wins regression for PC 119
# Finished wins regression for PC 120
# Finished wins regression for PC 121
# Finished wins regression for PC 122
# Finished wins regression for PC 123
# Finished wins regression for PC 124
# Finished wins regression for PC 125
# Finished wins regression for PC 126
# Finished wins regression for PC 127
# Finished wins regression for PC 128
# Finished wins regression for PC 129
# Finished wins regression for PC 130
# Finished wins regression for PC 131
# Finished wins regression for PC 132
# Finished wins regression for PC 133
# Finished wins regression for PC 134
# Finished wins regression for PC 135
# Finished wins regression for PC 136
# Finished wins regression for PC 137
# Finished wins regression for PC 138
# Finished wins regression for PC 139
# Finished wins regression for PC 140
# Finished wins regression for PC 141

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

results_wins = np.full((n_pcs, 2, n_maps), np.nan)   #n_repeats
coefs_wins = np.full((n_pcs, 2, n_maps), np.nan)   #n_repeats
for pc_id in np.arange(n_pcs):
    pairs = [(0,1),(2,3)]
    for pair_id, pair in enumerate(pairs):
        scores = []
        for f, (train, test) in enumerate(cv2.split()):
            # Initialize simple classifier
            clf = LogisticRegression(penalty='none', max_iter=300, class_weight='balanced') 

            # Z-score training and test cvISCs (based on training set)
            results_train = zscore(results[pc_id, pair_id*5, train][:, np.newaxis]) 
            results_test = zscore(results[pc_id, pair_id*5, test][:, np.newaxis])

            # Train logistic regression
            clf.fit(results_train, wins_stack[train, pair_id])

            # Predict test wins 
            pred = clf.predict(results_test)

            # Evaluate classifier accuracy
            score = accuracy_score(wins_stack[test, pair_id], pred)
            scores.append(score)
            
            # Keep coefficient
            coefs_wins[pc_id, pair_id, f] = clf.coef_
        results_wins[pc_id, pair_id] = np.array(scores)
    print(f"Finished wins regression for PC {pc_id}")
# Out:
# Finished wins regression for PC 0
# Finished wins regression for PC 1
# Finished wins regression for PC 2
# Finished wins regression for PC 3
# Finished wins regression for PC 4
# Finished wins regression for PC 5
# Finished wins regression for PC 6
# Finished wins regression for PC 7
# Finished wins regression for PC 8
# Finished wins regression for PC 9
# Finished wins regression for PC 10
# Finished wins regression for PC 11
# Finished wins regression for PC 12
# Finished wins regression for PC 13
# Finished wins regression for PC 14
# Finished wins regression for PC 15
# Finished wins regression for PC 16
# Finished wins regression for PC 17
# Finished wins regression for PC 18
# Finished wins regression for PC 19
# Finished wins regression for PC 20
# Finished wins regression for PC 21
# Finished wins regression for PC 22
# Finished wins regression for PC 23
# Finished wins regression for PC 24
# Finished wins regression for PC 25
# Finished wins regression for PC 26
# Finished wins regression for PC 27
# Finished wins regression for PC 28
# Finished wins regression for PC 29
# Finished wins regression for PC 30
# Finished wins regression for PC 31
# Finished wins regression for PC 32
# Finished wins regression for PC 33
# Finished wins regression for PC 34
# Finished wins regression for PC 35
# Finished wins regression for PC 36
# Finished wins regression for PC 37
# Finished wins regression for PC 38
# Finished wins regression for PC 39
# Finished wins regression for PC 40
# Finished wins regression for PC 41
# Finished wins regression for PC 42
# Finished wins regression for PC 43
# Finished wins regression for PC 44
# Finished wins regression for PC 45
# Finished wins regression for PC 46
# Finished wins regression for PC 47
# Finished wins regression for PC 48
# Finished wins regression for PC 49
# Finished wins regression for PC 50
# Finished wins regression for PC 51
# Finished wins regression for PC 52
# Finished wins regression for PC 53
# Finished wins regression for PC 54
# Finished wins regression for PC 55
# Finished wins regression for PC 56
# Finished wins regression for PC 57
# Finished wins regression for PC 58
# Finished wins regression for PC 59
# Finished wins regression for PC 60
# Finished wins regression for PC 61
# Finished wins regression for PC 62
# Finished wins regression for PC 63
# Finished wins regression for PC 64
# Finished wins regression for PC 65
# Finished wins regression for PC 66
# Finished wins regression for PC 67
# Finished wins regression for PC 68
# Finished wins regression for PC 69
# Finished wins regression for PC 70
# Finished wins regression for PC 71
# Finished wins regression for PC 72
# Finished wins regression for PC 73
# Finished wins regression for PC 74
# Finished wins regression for PC 75
# Finished wins regression for PC 76
# Finished wins regression for PC 77
# Finished wins regression for PC 78
# Finished wins regression for PC 79
# Finished wins regression for PC 80
# Finished wins regression for PC 81
# Finished wins regression for PC 82
# Finished wins regression for PC 83
# Finished wins regression for PC 84
# Finished wins regression for PC 85
# Finished wins regression for PC 86
# Finished wins regression for PC 87
# Finished wins regression for PC 88
# Finished wins regression for PC 89
# Finished wins regression for PC 90
# Finished wins regression for PC 91
# Finished wins regression for PC 92
# Finished wins regression for PC 93
# Finished wins regression for PC 94
# Finished wins regression for PC 95
# Finished wins regression for PC 96
# Finished wins regression for PC 97
# Finished wins regression for PC 98
# Finished wins regression for PC 99
# Finished wins regression for PC 100
# Finished wins regression for PC 101
# Finished wins regression for PC 102
# Finished wins regression for PC 103
# Finished wins regression for PC 104
# Finished wins regression for PC 105
# Finished wins regression for PC 106
# Finished wins regression for PC 107
# Finished wins regression for PC 108
# Finished wins regression for PC 109
# Finished wins regression for PC 110
# Finished wins regression for PC 111
# Finished wins regression for PC 112
# Finished wins regression for PC 113
# Finished wins regression for PC 114
# Finished wins regression for PC 115
# Finished wins regression for PC 116
# Finished wins regression for PC 117
# Finished wins regression for PC 118
# Finished wins regression for PC 119
# Finished wins regression for PC 120
# Finished wins regression for PC 121
# Finished wins regression for PC 122
# Finished wins regression for PC 123
# Finished wins regression for PC 124
# Finished wins regression for PC 125
# Finished wins regression for PC 126
# Finished wins regression for PC 127
# Finished wins regression for PC 128
# Finished wins regression for PC 129
# Finished wins regression for PC 130
# Finished wins regression for PC 131
# Finished wins regression for PC 132
# Finished wins regression for PC 133
# Finished wins regression for PC 134
# Finished wins regression for PC 135
# Finished wins regression for PC 136
# Finished wins regression for PC 137
# Finished wins regression for PC 138
# Finished wins regression for PC 139
# Finished wins regression for PC 140
# Finished wins regression for PC 141

# %%
results_wins.shape
# Out:
# (142, 2, 32)

# %%
np.save('regression_wins_results.npy', results_wins)

# %%
np.save('regression_wins_coefs.npy', coefs_wins)

# %%
results_wins = np.load('regression_wins_results.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_185432/2309285567.py in <module>
# ----> 1 results_wins = np.load('regression_wins_results.npy')
#
# ~/miniconda3/envs/ctf/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'regression_wins_results.npy'

# %%
coefs_wins = np.load('regression_wins_coefs.npy')

# %% [markdown]
# Make a dataframe of wins prediction accuracy for each PC

# %%
results_df_dict_wins = {'PC': [], 'wins coop': [], 'coef': []}

for pc_id in np.arange(n_pcs): 
    for game_id in np.arange(n_maps): #n_repeats
        wins_coop = np.mean(results_wins[pc_id, (0,1), game_id], axis=0)
        coef = np.mean(coefs_wins[pc_id, (0,1), game_id], axis=0)  #######?????????
        results_df_dict_wins['wins coop'].append(wins_coop)
        results_df_dict_wins['PC'].append(pc_id + 1)
        results_df_dict_wins['coef'].append(coef)

results_df_wins = pd.DataFrame(results_df_dict_wins)
results_df_wins
# Out:
#        PC  wins coop      coef
# 0       1   0.625000  0.148588
# 1       1   0.687500  0.139995
# 2       1   0.546875  0.157486
# 3       1   0.453125  0.168560
# 4       1   0.468750  0.167665
# ...   ...        ...       ...
# 4539  142   0.500000  0.064294
# 4540  142   0.468750  0.068474
# 4541  142   0.593750  0.057638
# 4542  142   0.468750  0.078981
# 4543  142   0.484375  0.080700
#
# [4544 rows x 3 columns]

# %% [markdown]
# Plot wins prediction accuaracy

# %%
cols = ['red' if np.mean(results_df_wins[results_df_wins['PC']==x]['coef']) < 0
       else 'blue' for x in range(1,143)]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='wins coop', data=results_df_wins, palette=cols) #color='gray')
ax.set_ylim(0.4, .65)
ax.set_title('Wins Prediction Accuracy from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('wins prediction accuracy', fontsize=16);


# insert horizontal line (gray dotted) at 50

# %% [markdown]
# Predict scores using cvISC. results_scores is of shape 142 PCs, 2 teams, 32 folds

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from scipy.stats import pearsonr

results_scores = np.full((n_pcs, 2, n_maps), np.nan)   #n_repeats
coefs_scores = np.full((n_pcs, 2, n_maps), np.nan)
for pc_id in np.arange(n_pcs):
    pairs = [(0, (0,1)), (5, (2,3))]
    for pair_id, pair in pairs:
        scores = []
        for f, (train, test) in enumerate(cv2.split()):
            # Initialize simple classifier
            clf = LinearRegression() 

            # Z-score training and test cvISCs (based on training set)
            results_train = zscore(results[pc_id, pair_id, train][:, np.newaxis]) 
            results_test = zscore(results[pc_id, pair_id, test][:, np.newaxis])

            # Train logistic regression
            clf.fit(results_train, scores_stack[train, pair_id//5])

            # Predict test wins 
            pred = clf.predict(results_test)

            # Evaluate classifier accuracy
            r = pearsonr(pred, scores_stack[test, pair_id//5])[0]
            scores.append(r)
            
            # Keep coefficient
            coefs_scores[pc_id, pair_id//5, f] = clf.coef_
        results_scores[pc_id, pair_id//5] = np.array(scores)
    print(f"Finished scores regression for PC {pc_id}")
# Out:
# Finished scores regression for PC 0
# Finished scores regression for PC 1
# Finished scores regression for PC 2
# Finished scores regression for PC 3
# Finished scores regression for PC 4
# Finished scores regression for PC 5
# Finished scores regression for PC 118
# Finished scores regression for PC 119
# Finished scores regression for PC 120
# Finished scores regression for PC 121
# Finished scores regression for PC 122
# Finished scores regression for PC 123
# Finished scores regression for PC 124
# Finished scores regression for PC 125
# Finished scores regression for PC 126
# Finished scores regression for PC 127
# Finished scores regression for PC 128
# Finished scores regression for PC 129
# Finished scores regression for PC 130
# Finished scores regression for PC 131
# Finished scores regression for PC 132
# Finished scores regression for PC 133
# Finished scores regression for PC 134
# Finished scores regression for PC 135
# Finished scores regression for PC 136
# Finished scores regression for PC 137
# Finished scores regression for PC 138
# Finished scores regression for PC 139
# Finished scores regression for PC 140
# Finished scores regression for PC 141

# %%
np.save('regression_scores_results.npy', results_scores)

# %%
np.save('regression_scores_coefs.npy', coefs_scores)

# %%
results_scores = np.load('regression_scores_results.npy')

# %%
coefs_scores = np.load('regression_scores_coefs.npy')

# %%
results_scores.shape
# Out:
# (142, 2, 32)

# %% [markdown]
# Load results into a dataframe and plot

# %%
results_df_dict_scores = {'PC': [], 'scores coop': [], 'coef': []}# 'score diffs coop': [],, 'score diffs comp': []} #'wins comp': [],

coop_ids = (0, 5)
comp_ids = (1, 2, 3, 4)
for pc_id in np.arange(n_pcs): 
    for game_id in np.arange(n_maps):# * n_repeats):
        #scores_coop_diffs = np.mean(results_scores_diffs[pc_id])
        scores_coop = np.mean(results_scores[pc_id, :, game_id]) #np.mean(results_scores[pc_id]) 
        coef = np.mean(coefs_scores[pc_id, :, game_id])
        #results_df_dict_scores['score diffs coop'].append(scores_coop_diffs)
        results_df_dict_scores['scores coop'].append(scores_coop)
        results_df_dict_scores['PC'].append(pc_id + 1)
        results_df_dict_scores['coef'].append(coef)

results_df_scores = pd.DataFrame(results_df_dict_scores)
results_df_scores
# Out:
#        PC  scores coop      coef
# 0       1     0.160280  0.082927
# 1       1     0.111790  0.089368
# 2       1     0.089536  0.091289
# 3       1    -0.194282  0.107866
# 4       1     0.157924  0.054112
# ...   ...          ...       ...
# 4539  142    -0.017284  0.085065
# 4540  142     0.008130  0.082271
# 4541  142     0.020642  0.078547
# 4542  142    -0.200087  0.101144
# 4543  142    -0.195768  0.097542
#
# [4544 rows x 3 columns]

# %%
cols = ['red' if np.mean(results_df_scores[results_df_scores['PC']==x]['coef']) < 0
       else 'blue' for x in range(1,143)]
#cols = ['red' if np.mean(results_df_scores_diff[results_df_scores_diff['PC']==x]['scores diff coop']) < 0 else 'blue' for x in range(1,143)]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='scores coop', data=results_df_scores, palette=cols)#color='gray')
ax.set_ylim(-.2, .3)
ax.set_title('Scores Prediction from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('scores prediction pearson r', fontsize=16);

# %% [markdown]
# Predict score differences using cvISC. results_scores_diff is of shape 142 PCs, 32 folds

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from scipy.stats import pearsonr

results_scores_diff = np.full((n_pcs, n_maps), np.nan)   #n_repeats
coefs_scores_diff = np.full((n_pcs, n_maps), np.nan)
for pc_id in np.arange(n_pcs):
    scores = []
    for f, (train, test) in enumerate(cv2.split()):
        # Initialize simple classifier
        clf = LinearRegression() 

        # Z-score training and test cvISCs (based on training set)
        results_train = zscore((results[pc_id, 0, train]-results[pc_id, 5, train])[:, np.newaxis]) 
        results_test = zscore((results[pc_id, 0, test]-results[pc_id, 5, test])[:, np.newaxis])

        # Train logistic regression
        clf.fit(results_train, scores_stack[train, 0]-scores_stack[train, 1])

        # Predict test wins 
        pred = clf.predict(results_test)

        # Evaluate classifier accuracy
        r = pearsonr(pred, scores_stack[test, 0]-scores_stack[test, 1])[0]
        scores.append(r)
        
        # Keep coefficient
        coefs_scores_diff[pc_id, f] = clf.coef_
    results_scores_diff[pc_id] = np.array(scores)
    print(f"Finished scores regression for PC {pc_id}") 
print(f"Shape of results: {results_scores_diff.shape}")
# Out:
# Finished scores regression for PC 0
# Finished scores regression for PC 1
# Finished scores regression for PC 2
# Finished scores regression for PC 3
# Finished scores regression for PC 4
# Finished scores regression for PC 5
# Finished scores regression for PC 6
# Finished scores regression for PC 7
# Finished scores regression for PC 8
# Finished scores regression for PC 9
# Finished scores regression for PC 10
# Finished scores regression for PC 11
# Finished scores regression for PC 12
# Finished scores regression for PC 13
# Finished scores regression for PC 14
# Finished scores regression for PC 15
# Finished scores regression for PC 16
# Finished scores regression for PC 17
# Finished scores regression for PC 18
# Finished scores regression for PC 19
# Finished scores regression for PC 20
# Finished scores regression for PC 21
# Finished scores regression for PC 22
# Finished scores regression for PC 23
# Finished scores regression for PC 24
# Finished scores regression for PC 25
# Finished scores regression for PC 26
# Finished scores regression for PC 27
# Finished scores regression for PC 28
# Finished scores regression for PC 29
# Finished scores regression for PC 30
# Finished scores regression for PC 31
# Finished scores regression for PC 32
# Finished scores regression for PC 33
# Finished scores regression for PC 34
# Finished scores regression for PC 35
# Finished scores regression for PC 36
# Finished scores regression for PC 37
# Finished scores regression for PC 38
# Finished scores regression for PC 39
# Finished scores regression for PC 40
# Finished scores regression for PC 41
# Finished scores regression for PC 42
# Finished scores regression for PC 43
# Finished scores regression for PC 44
# Finished scores regression for PC 45
# Finished scores regression for PC 46
# Finished scores regression for PC 47
# Finished scores regression for PC 48
# Finished scores regression for PC 49
# Finished scores regression for PC 50
# Finished scores regression for PC 51
# Finished scores regression for PC 52
# Finished scores regression for PC 53
# Finished scores regression for PC 54
# Finished scores regression for PC 55
# Finished scores regression for PC 56
# Finished scores regression for PC 57
# Finished scores regression for PC 58
# Finished scores regression for PC 59
# Finished scores regression for PC 60
# Finished scores regression for PC 61
# Finished scores regression for PC 62
# Finished scores regression for PC 63
# Finished scores regression for PC 64
# Finished scores regression for PC 65
# Finished scores regression for PC 66
# Finished scores regression for PC 67
# Finished scores regression for PC 68
# Finished scores regression for PC 69
# Finished scores regression for PC 70
# Finished scores regression for PC 71
# Finished scores regression for PC 72
# Finished scores regression for PC 73
# Finished scores regression for PC 74
# Finished scores regression for PC 75
# Finished scores regression for PC 76
# Finished scores regression for PC 77
# Finished scores regression for PC 78
# Finished scores regression for PC 79
# Finished scores regression for PC 80
# Finished scores regression for PC 81
# Finished scores regression for PC 82
# Finished scores regression for PC 83
# Finished scores regression for PC 84
# Finished scores regression for PC 85
# Finished scores regression for PC 86
# Finished scores regression for PC 87
# Finished scores regression for PC 88
# Finished scores regression for PC 89
# Finished scores regression for PC 90
# Finished scores regression for PC 91
# Finished scores regression for PC 92
# Finished scores regression for PC 93
# Finished scores regression for PC 94
# Finished scores regression for PC 95
# Finished scores regression for PC 96
# Finished scores regression for PC 97
# Finished scores regression for PC 98
# Finished scores regression for PC 99
# Finished scores regression for PC 100
# Finished scores regression for PC 101
# Finished scores regression for PC 102
# Finished scores regression for PC 103
# Finished scores regression for PC 104
# Finished scores regression for PC 105
# Finished scores regression for PC 106
# Finished scores regression for PC 107
# Finished scores regression for PC 108
# Finished scores regression for PC 109
# Finished scores regression for PC 110
# Finished scores regression for PC 111
# Finished scores regression for PC 112
# Finished scores regression for PC 113
# Finished scores regression for PC 114
# Finished scores regression for PC 115
# Finished scores regression for PC 116
# Finished scores regression for PC 117
# Finished scores regression for PC 118
# Finished scores regression for PC 119
# Finished scores regression for PC 120
# Finished scores regression for PC 121
# Finished scores regression for PC 122
# Finished scores regression for PC 123
# Finished scores regression for PC 124
# Finished scores regression for PC 125
# Finished scores regression for PC 126
# Finished scores regression for PC 127
# Finished scores regression for PC 128
# Finished scores regression for PC 129
# Finished scores regression for PC 130
# Finished scores regression for PC 131
# Finished scores regression for PC 132
# Finished scores regression for PC 133
# Finished scores regression for PC 134
# Finished scores regression for PC 135
# Finished scores regression for PC 136
# Finished scores regression for PC 137
# Finished scores regression for PC 138
# Finished scores regression for PC 139
# Finished scores regression for PC 140
# Finished scores regression for PC 141
# Shape of results: (142, 32)

# %%
np.save('regression_scores_diffs_results.npy', results_scores_diff)

# %%
np.save('regression_scores_diffs_coefs.npy', coefs_scores_diff)

# %%
results_scores_diff = np.load('regression_scores_diffs_results.npy')

# %%
coefs_scores_diff = np.load('regression_scores_diffs_coefs.npy')

# %% [markdown]
# Load results into a dataframe and plot

# %%
results_df_dict_scores_diff = {'PC': [], 'scores diff coop': [], 'coef': []}# 'score diffs coop': [],, 'score diffs comp': []} #'wins comp': [],

coop_ids = (0, 5)
comp_ids = (1, 2, 3, 4)
for pc_id in np.arange(n_pcs): 
    for game_id in np.arange(n_maps):# * n_repeats):
        #scores_coop_diffs = np.mean(results_scores_diffs[pc_id])
        scores_coop = results_scores_diff[pc_id, game_id] #np.mean(results_scores_diff[pc_id]) 
        coef = coefs_scores_diff[pc_id, game_id] #np.mean(coefs_scores_diff[pc_id]) 
        #results_df_dict_scores['score diffs coop'].append(scores_coop_diffs)
        results_df_dict_scores_diff['scores diff coop'].append(scores_coop)
        results_df_dict_scores_diff['PC'].append(pc_id + 1)
        results_df_dict_scores_diff['coef'].append(coef)

results_df_scores_diff = pd.DataFrame(results_df_dict_scores_diff)
results_df_scores_diff
# Out:
#        PC  scores diff coop       coef
# 0       1          0.430816 -13.544762
# 1       1          0.522422 -13.141844
# 2       1          0.269432 -14.252216
# 3       1         -0.132406 -15.520132
# 4       1          0.032118 -14.666750
# ...   ...               ...        ...
# 4539  142          0.176809  -5.255383
# 4540  142          0.083884  -5.646678
# 4541  142          0.306512  -4.901135
# 4542  142         -0.156591  -6.804247
# 4543  142         -0.226136  -6.866826
#
# [4544 rows x 3 columns]

# %%
#cols = ['red' if np.mean(results_df_scores_diff[results_df_scores_diff['PC']==x]['scores diff coop']) < 0 else 'blue' for x in range(1,143)]
cols = ['red' if np.mean(results_df_scores_diff[results_df_scores_diff['PC']==x]['coef']) < 0
       else 'blue' for x in range(1,143)]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='scores diff coop', data=results_df_scores_diff, palette=cols)#color='gray')
ax.set_ylim(-.3, .4)
ax.set_title('Scores Differences Prediction from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('scores differences prediction pearson r', fontsize=16);

# %% [markdown]
# ### Multiple Regression
# Wins multiple regression

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

results_wins_multi = np.full((2, n_maps), np.nan)   #n_repeats
pairs = [(0,1),(2,3)]
for pair_id, pair in enumerate(pairs):
    scores = []
    for f, (train, test) in enumerate(cv2.split()):
        # Initialize simple classifier
        clf = LogisticRegression(penalty='none', max_iter=300, class_weight='balanced') 

        # Z-score training cvISCs
        results_train = zscore(np.moveaxis(results[..., pair_id*5, train],0,1))
        results_test = zscore(np.moveaxis(results[..., pair_id*5, test],0,1))

        # Train on train cvISCs
        clf.fit(results_train, wins_stack[train, pair_id])

        # Predict test cvISCs 
        pred = clf.predict(results_test)

        # Evaluate accuracy
        score = accuracy_score(wins_stack[test, pair_id], pred)
        scores.append(score)
    results_wins_multi[pair_id] = np.array(scores)
print(f"Finished wins regression")
# Out:
# Finished wins regression

# %%
results_wins_multi.shape
# Out:
# (2, 32)

# %%
results_wins_multi
# Out:
# array([[0.71875, 0.78125, 0.75   , 0.75   , 0.6875 , 0.6875 , 0.8125 ,
#         0.71875, 0.84375, 0.6875 , 0.8125 , 0.59375, 0.78125, 0.65625,
#         0.75   , 0.71875, 0.78125, 0.8125 , 0.5625 , 0.6875 , 0.8125 ,
#         0.6875 , 0.78125, 0.78125, 0.65625, 0.5625 , 0.71875, 0.75   ,
#         0.84375, 0.625  , 0.625  , 0.71875],
#        [0.84375, 0.71875, 0.6875 , 0.65625, 0.78125, 0.6875 , 0.65625,
#         0.5625 , 0.75   , 0.6875 , 0.8125 , 0.75   , 0.78125, 0.65625,
#         0.59375, 0.78125, 0.75   , 0.8125 , 0.625  , 0.6875 , 0.65625,
#         0.78125, 0.90625, 0.84375, 0.65625, 0.625  , 0.6875 , 0.625  ,
#         0.78125, 0.46875, 0.71875, 0.71875]])

# %%
np.save('results_wins_multi.npy', results_wins_multi)

# %%
results_wins_multi = np.load('results_wins_multi.npy')

# %% [markdown]
# Bootstrap evaluation

# %%
np.mean(results_wins_multi)
# Out:
# 0.71728515625

# %%
results_wins_maps = np.mean(results_wins_multi, axis=0)

n_maps = 32
n_bootstraps = 10000

bootstrap_dist = []
for i in np.arange(n_bootstraps):
    bootstrap_dist.append(np.mean(np.random.choice(results_wins_maps, n_maps, replace=True)))

# %%
# bootstrap distribution and mean
sns.displot(bootstrap_dist)
plt.xlabel('mean accuracy')
plt.axvline(np.mean(results_wins_maps), c='r')

# %%
# 95% confidence range
np.percentile(bootstrap_dist, 2.5), np.percentile(bootstrap_dist, 97.5)
# Out:
# (0.69287109375, 0.74072265625)

# %%
# Correlation of prediction accuracies for the 2 teams on each map
from scipy.stats import pearsonr
pearsonr(results_wins_multi[0], results_wins_multi[1])
# Out:
# (0.4138404798528727, 0.018544740639397428)

# %% [markdown]
# Extract and plot the coefficients

# %%
wins_multi_coefs = clf.coef_

# %%
dict_wins_multi_coef = {'PC': [], 'coef': []}

for pc_id in np.arange(n_pcs): 
    dict_wins_multi_coef['coef'].append(wins_multi_coefs[0, pc_id])
    dict_wins_multi_coef['PC'].append(pc_id + 1)

df_wins_multi_coef = pd.DataFrame(dict_wins_multi_coef)

# %%
cols = ['red' if x < 0 else 'blue' for x in df_scores_multi_coef.coef]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='coef', data=df_wins_multi_coef, palette=cols) #color='gray')
ax.set_ylim(-0.7, 0.7)
ax.set_title('Wins Multiple Regression Coefficients from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('coefficient', fontsize=16);

# %% [markdown]
# Scores multiple regression

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

results_scores_multi = np.full((2, n_maps), np.nan)   #n_repeats
pairs = [(0,1),(2,3)]
for pair_id, pair in enumerate(pairs):
    scores = []
    for f, (train, test) in enumerate(cv2.split()):
        # Initialize simple classifier
        clf = LinearRegression() 

        # Z-score training cvISCs
        results_train = zscore(np.moveaxis(results[..., pair_id*5, train],0,1))
        results_test = zscore(np.moveaxis(results[..., pair_id*5, test],0,1))

        # Train on train cvISCs
        clf.fit(results_train, scores_stack[train, pair_id])

        # Predict test cvISCs 
        pred = clf.predict(results_test)

        # Evaluate accuracy
        r = pearsonr(pred, scores_stack[test, pair_id])[0]
        scores.append(r)
    results_scores_multi[pair_id] = np.array(scores)
print(f"Finished scores regression")
# Out:
# Finished scores regression

# %%
results_scores_multi.shape
# Out:
# (2, 32)

# %% [markdown]
# Bootstrap evaluation

# %%
np.mean(results_scores_multi)
# Out:
# 0.5626252269098615

# %%
results_scores_maps = np.mean(results_scores_multi, axis=0)

n_maps = 32
n_bootstraps = 10000

bootstrap_dist = []
for i in np.arange(n_bootstraps):
    bootstrap_dist.append(np.mean(np.random.choice(results_scores_maps, n_maps, replace=True)))

# %%
# bootstrap distribution and mean
sns.displot(bootstrap_dist)
plt.xlabel('mean pearsonr')
plt.axvline(np.mean(results_scores_maps), c='r')

# %%
# 95% confidence range
np.percentile(bootstrap_dist, 2.5), np.percentile(bootstrap_dist, 97.5)
# Out:
# (0.5267580410322992, 0.5977357125620031)

# %%
# Correlation of prediction pearsonr for the 2 teams on each map
from scipy.stats import pearsonr
pearsonr(results_scores_multi[0], results_scores_multi[1])
# Out:
# (0.4762552721024862, 0.005861201938305223)

# %% [markdown]
# Extract and plot the coefficients

# %%
scores_multi_coefs = clf.coef_
scores_multi_coefs.shape
# Out:
# (142,)

# %%
dict_scores_multi_coef = {'PC': [], 'coef': []}

for pc_id in np.arange(n_pcs): 
    dict_scores_multi_coef['coef'].append(scores_multi_coefs[pc_id])
    dict_scores_multi_coef['PC'].append(pc_id + 1)

df_scores_multi_coef = pd.DataFrame(dict_scores_multi_coef)

# %%
cols = ['red' if x < 0 else 'blue' for x in df_wins_multi_coef.coef]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='coef', data=df_scores_multi_coef, palette=cols)# color='gray')
ax.set_ylim(-0.7, 0.7)
ax.set_title('Scores Multiple Regression Coefficients from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('coefficient', fontsize=16);

# %% [markdown]
# Score differences multiple regression

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

results_score_diffs_multi = np.full((n_maps), np.nan)   #n_repeats
scores=[]
for f, (train, test) in enumerate(cv2.split()):
    # Initialize simple classifier
    clf = LinearRegression() 

    # Z-score training cvISCs
    results_train = zscore(np.moveaxis(results[..., 0, train]-results[..., 5, train],0,1)) 
    results_test = zscore(np.moveaxis(results[..., 0, train]-results[..., 5, train],0,1))

    # Train on train cvISCs
    clf.fit(results_train, scores_stack[train, 0]-scores_stack[train, 1])

    # Predict test cvISCs 
    pred = clf.predict(results_test)

    # Evaluate accuracy
    r = pearsonr(pred, scores_stack[train, 0]-scores_stack[train, 1])[0]
    scores.append(r)
results_score_diffs_multi = np.array(scores)
print(f"Finished scores regression")
# Out:
# Finished scores regression

# %%
results_score_diffs_multi.shape
# Out:
# (32,)

# %% [markdown]
# Bootstrap evaluation

# %%
np.mean(results_score_diffs_multi)
# Out:
# 0.7275004457279404

# %%
#results_scores_maps = results_score_diffs_multi

n_maps = 32
n_bootstraps = 10000

bootstrap_dist = []
for i in np.arange(n_bootstraps):
    bootstrap_dist.append(np.mean(np.random.choice(results_score_diffs_multi, n_maps, replace=True)))

# %%
# bootstrap distribution and mean
sns.displot(bootstrap_dist)
plt.xlabel('mean pearsonr')
plt.axvline(np.mean(results_score_diffs_multi), c='r')

# %%
# 95% confidence range
np.percentile(bootstrap_dist, 2.5), np.percentile(bootstrap_dist, 97.5)
# Out:
# (0.7266427505025734, 0.7283770354564391)

# %% [markdown]
# Extract and plot the coefficients

# %%
score_diffs_multi_coefs = clf.coef_
score_diffs_multi_coefs.shape
# Out:
# (142,)

# %%
dict_score_diffs_multi_coef = {'PC': [], 'coef': []}

for pc_id in np.arange(n_pcs): 
    dict_score_diffs_multi_coef['coef'].append(score_diffs_multi_coefs[pc_id])
    dict_score_diffs_multi_coef['PC'].append(pc_id + 1)

df_score_diffs_multi_coef = pd.DataFrame(dict_score_diffs_multi_coef)

# %%
cols = ['red' if x < 0 else 'blue' for x in df_wins_multi_coef.coef]
fig, ax = plt.subplots(figsize=(50, 5))
sns.barplot(x='PC', y='coef', data=df_score_diffs_multi_coef, palette=cols)#color='gray')
ax.set_ylim(-35, 35)
ax.set_title('Score Differences Multiple Regression Coefficients from cvISCs for 142 PCs', fontsize=20)
plt.xlabel('PC', fontsize=16);
plt.ylabel('coefficient', fontsize=16);
